# %%
import pandas as pd
import inflect
p = inflect.engine()
import requests
import pygame
import base64
import io
import random
from moviepy.editor import *
import os
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.11.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
TextClip.list('font')
# Out:
# ['AvantGarde-Book',
#  'AvantGarde-BookOblique',
#  'AvantGarde-Demi',
#  'AvantGarde-DemiOblique',
#  'Bookman-Demi',
#  'Bookman-DemiItalic',
#  'Bookman-Light',
#  'Bookman-LightItalic',
#  'Courier-BoldOblique',
#  'fixed',
#  'Helvetica-BoldOblique',
#  'Helvetica-Narrow',
#  'Helvetica-Narrow-Bold',
#  'Helvetica-Narrow-BoldOblique',
#  'Helvetica-Narrow-Oblique',
#  'NewCenturySchlbk-Bold',
#  'NewCenturySchlbk-BoldItalic',
#  'NewCenturySchlbk-Italic',
#  'NewCenturySchlbk-Roman',
#  'Palatino-BoldItalic',
#  'Palatino-Roman',
#  'Times-BoldItalic',
#  '.Al-Bayan-PUA-Bold',
#  '.Al-Bayan-PUA-Plain',
#  '.Al-Nile-PUA',
#  '.Al-Nile-PUA-Bold',
#  '.Al-Tarikh-PUA',
#  '.Apple-Color-Emoji-UI',
#  '.Apple-SD-Gothic-NeoI-Bold',
#  '.Apple-SD-Gothic-NeoI-ExtraBold',
#  '.Apple-SD-Gothic-NeoI-Heavy',
#  '.Apple-SD-Gothic-NeoI-Light',
#  '.Apple-SD-Gothic-NeoI-Medium',
#  '.Apple-SD-Gothic-NeoI-Regular',
#  '.Apple-SD-Gothic-NeoI-SemiBold',
#  '.Apple-SD-Gothic-NeoI-Thin',
# ...

# %%
Kohinoor-Gujarati-Bold

Gujarati (India) 	WaveNet 	gu-IN 	gu-IN-Wavenet-A 	FEMALE 	Your browser doesn't support the audio element.
Gujarati (India) 	WaveNet 	gu-IN 	gu-IN-Wavenet-B 	MALE



Devanagari
Hindi (India) 	Neural2 	hi-IN 	hi-IN-Neural2-A 	FEMALE 	Your browser doesn't support the audio element.
Hindi (India) 	Neural2 	hi-IN 	hi-IN-Neural2-B 	MALE 	Your browser doesn't support the audio element.
Hindi (India) 	Neural2 	hi-IN 	hi-IN-Neural2-C 	MALE 	Your browser doesn't support the audio element.
Hindi (India) 	Neural2 	hi-IN 	hi-IN-Neural2-D 	FEMALE



Kannada-MN
Kannada (India) 	WaveNet 	kn-IN 	kn-IN-Wavenet-A 	FEMALE 	Your browser doesn't support the audio element.
Kannada (India) 	WaveNet 	kn-IN 	kn-IN-Wavenet-B 	MALE 	Your browser doesn't support the audio element.
Kannada (India) 	WaveNet 	kn-IN 	kn-IN-Wavenet-C 	FEMALE 	Your browser doesn't support the audio element.
Kannada (India) 	WaveNet 	kn-IN 	kn-IN-Wavenet-D 	MALE





Malayalam-MN
Malayalam (India) 	WaveNet 	ml-IN 	ml-IN-Wavenet-A 	FEMALE 	Your browser doesn't support the audio element.
Malayalam (India) 	WaveNet 	ml-IN 	ml-IN-Wavenet-B 	MALE 	Your browser doesn't support the audio element.
Malayalam (India) 	WaveNet 	ml-IN 	ml-IN-Wavenet-C 	FEMALE 	Your browser doesn't support the audio element.
Malayalam (India) 	WaveNet 	ml-IN 	ml-IN-Wavenet-D 	MALE




ITFDevanagari-Marathi-Bold
Marathi (India) 	WaveNet 	mr-IN 	mr-IN-Wavenet-A 	FEMALE 	Your browser doesn't support the audio element.
Marathi (India) 	WaveNet 	mr-IN 	mr-IN-Wavenet-B 	MALE 	Your browser doesn't support the audio element.
Marathi (India) 	WaveNet 	mr-IN 	mr-IN-Wavenet-C 	FEMALE





Punjabi (India) 	WaveNet 	pa-IN 	pa-IN-Wavenet-A 	FEMALE 	Your browser doesn't support the audio element.
Punjabi (India) 	WaveNet 	pa-IN 	pa-IN-Wavenet-B 	MALE 	Your browser doesn't support the audio element.
Punjabi (India) 	WaveNet 	pa-IN 	pa-IN-Wavenet-C 	FEMALE 	Your browser doesn't support the audio element.
Punjabi (India) 	WaveNet 	pa-IN 	pa-IN-Wavenet-D 	MALE






Tamil (India) 	WaveNet 	ta-IN 	ta-IN-Wavenet-A 	FEMALE 	Your browser doesn't support the audio element.
Tamil (India) 	WaveNet 	ta-IN 	ta-IN-Wavenet-B 	MALE 	Your browser doesn't support the audio element.
Tamil (India) 	WaveNet 	ta-IN 	ta-IN-Wavenet-C 	FEMALE 	Your browser doesn't support the audio element.
Tamil (India) 	WaveNet 	ta-IN 	ta-IN-Wavenet-D 	MALE




Bengali (India) 	WaveNet 	bn-IN 	bn-IN-Wavenet-A 	FEMALE 	Your browser doesn't support the audio element.
Bengali (India) 	WaveNet 	bn-IN 	bn-IN-Wavenet-B 	MALE 	Your browser doesn't support the audio element.
Bengali (India) 	WaveNet 	bn-IN 	bn-IN-Wavenet-C 	FEMALE 	Your browser doesn't support the audio element.
Bengali (India) 	WaveNet 	bn-IN 	bn-IN-Wavenet-D 	MALE






Azure -- No Time Stamp?

mr-IN 	Marathi (India) 	mr-IN-AarohiNeural (Female)
mr-IN-ManoharNeural (Male)



ml-IN 	Malayalam (India) 	ml-IN-SobhanaNeural2 (Female)
ml-IN-MidhunNeural2 (Male)


ta-IN 	Tamil (India) 	ta-IN-PallaviNeural (Female)
ta-IN-ValluvarNeural (Male)


te-IN 	Telugu (India) 	te-IN-ShrutiNeural (Female)
te-IN-MohanNeural (Male)


ur-IN 	Urdu (India) 	ur-IN-GulNeural (Female)
ur-IN-SalmanNeural (Male)

# %%
a='Kohinoor-Telugu-Bold'
background = '/Users/saml16/projects/Elections_info/static/images/image_set/image_colors/yellow/name.png'
video_text = {'name':'Cases', 'content':'52 11 00 Crimina isabadthing'}
text_clip_props={}
background = ImageClip(background, duration=2)

text2 = TextClip("తెలుగును పరీక్షిస్తోంది", size=(int(background.w *0.9),600), align=text_clip_props.get('align','North'), font=text_clip_props.get('font',a), fontsize=text_clip_props.get('fontsize',120), color=text_clip_props.get('color','White'), method=text_clip_props.get('method','caption'), stroke_color=text_clip_props.get('stroke_color','GhostWhite'), stroke_width=text_clip_props.get('stroke_width',1)).set_position((0.05,0.43),relative=True).set_duration(2)
name_v=CompositeVideoClip([background,text2])
name_v.ipython_display(fps=120)
# Out:
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
p = inflect.engine()
help(p.number_to_words)
# Out:
# Help on method number_to_words in module inflect:
#
# number_to_words(num: Union[numbers.Number, Annotated[str, FieldInfo(default=PydanticUndefined, min_length=1, extra={})]], wantlist: bool = False, group: int = 0, comma: Union[Any, str] = ',', andword: str = 'and', zero: str = 'zero', one: str = 'one', decimal: Union[Any, str] = 'point', threshold: Optional[int] = None) -> Union[str, List[str]] method of inflect.engine instance
#     Return a number in words.
#
#     group = 1, 2 or 3 to group numbers before turning into words
#     comma: define comma
#
#     andword:
#         word for 'and'. Can be set to ''.
#         e.g. "one hundred and one" vs "one hundred one"
#
#     zero: word for '0'
#     one: word for '1'
#     decimal: word for decimal point
#     threshold: numbers above threshold not turned into words
#
#     parameters not remembered from last call. Departure from Perl version.

# %%
working_dir= "/Users/saml16/projects/Elections_info/static/"
GCP_key='AIzaSyA9zk7xH_5b06s3Hda8BfVdGpbEkiYNeGc' 


voice_options=[  {"name" : "en-IN-Neural2-A",  "pitch": -4.4,"speakingRate": 0.93}, 
    { "name": "en-IN-Neural2-A", "pitch": 0 ,"speakingRate": 1},
    { "name": "en-IN-Neural2-A", "pitch": 2 ,"speakingRate": 1},
    {"name" : "en-IN-Neural2-D", "pitch": -3.6,"speakingRate": 0.93},
    {"name" : "en-IN-Neural2-D", "pitch": 0 ,"speakingRate": 1},
    { "name" : "en-IN-Neural2-D", "pitch": 3.2 ,"speakingRate": 1.0}, 
    {"name" : "en-IN-Neural2-B", "pitch": -5.6,"speakingRate": 0.89},
    { "name" : "en-IN-Neural2-B","pitch": 0 ,"speakingRate": 1},
    {"name" : "en-IN-Neural2-B", "pitch": 3.2 ,"speakingRate": 0.93},
    {"name" : "en-IN-Neural2-C", "pitch": -14.0,"speakingRate": 1.0},
    {"name" : "en-IN-Neural2-C", "pitch": 0 ,"speakingRate": 1}]

background_image_folder_path='/Users/saml16/projects/Elections_info/static/images/image_set/image_colors/'
background_color_folder_path=['yellow/', 'green/','blue/']
background_images_names= {'name': 'name.png', 
                    'party':'name.png',
                    'constituency':'victory.png',
                    'age':'victory.png', 
                    'education':'education.png',
                    'criminal_cases':'cases.png',
                    'assets':'assets.png',
                    'liabilities':'assets.png'}

profile_path="/Users/saml16/projects/Elections_info/static/Loksabha2019/Winners/images/"
party_path="/Users/saml16/projects/Elections_info/static/Party/images/"
output_location = '/Users/saml16/projects/Elections_info/static/Loksabha2019/Winners/videos/'

audio_clip_location='/Users/saml16/projects/Elections_info/static/Loksabha2019/Winners/audio/'

text_clip_props={'align':'North', 'font':'Futura-Bold', 'color':'White', 'method':'caption', 'stroke_color':'GhostWhite', 'stroke_width':1}

notice_image_path='/Users/saml16/projects/Elections_info/static/images/notice.png'

profile_path="/Users/saml16/projects/Elections_info/static/Loksabha2019/Winners/images/"
party_path="/Users/saml16/projects/Elections_info/static/Party/images/"

# %%
# function for Name
def describe_name(name):
    name=str(name)
    return f' Candidate name: <prosody rate="slow">{name}</prosody><mark name="name"/>'

# function for party
def describe_party_affiliation(party_abb, party_name):
    party_name=str(party_name if party_name else party_abb)
    if party_abb in party_name:
        party_name = party_name.replace('('+party_abb+')',"")
    if party_name.lower() == 'independent':
        return ', is an Independent candidate <mark name="party"/>'
    elif 'party' in party_name.lower():
        return f', is a member of the {party_name} <mark name="party"/>'  
    else:
        return f', is a member of the {party_name} party <mark name="party"/>'

def describe_constituency(constituency):
    constituency=str(constituency)
    return f', has won the {constituency} seat<mark name="constituency"/>'
    
# function for age
def describe_age(age):
    age=str(age)
    return f', at the age of {age}<mark name="age"/>'


# function for education 
def describe_education(education_level):
    education_level=str(education_level)
    education_descriptions = {
        'Doctorate': ', holds a Doctorate degree<mark name="education"/>',
        'Graduate': ', holds a Graduate degree<mark name="education"/>',
        'Post Graduate': ', holds a Post Graduate degree <mark name="education"/>',
        '10th Pass': ', has completed secondary education<mark name="education"/>',
        '12th Pass': ', has completed higher secondary education<mark name="education"/>',
        'Graduate Professional': ', is a Graduate Professional<mark name="education"/>',
        '5th Pass': ', with primary education<mark name="education"/>',
        '8th Pass': ', has completed middle school<mark name="education"/>',
        'Others': ', has other educational qualifications<mark name="education"/>',
        'Illiterate': ', is illiterate<mark name="age"/>',
        'Literate': ',  is literate but with unspecified formal education<mark name="education"/>',
        'Not Given': ', has unspecified educational background<mark name="education"/>'
    }
    return education_descriptions.get(education_level, ' <mark name="education"/>')



# function for criminal_cases 
def describe_criminal_cases(cases):
    
    try:
        num_cases = int(cases)
    except ValueError:
        return ', with an unknown legal standing<mark name="criminal_cases"/> '
    if num_cases == 0:
        return ', with no criminal cases on record<mark name="criminal_cases"/>'
    elif num_cases == 1:
        return ', with 1 criminal case on record<mark name="criminal_cases"/>'
    else:
        return f', <google:style name="apologetic">with {num_cases} criminal cases on record</google:style><mark name="criminal_cases"/>'

    

# function for assets,assets_in_words,liabilities,liabilities_in_words
def convert_money_to_words(amount_words, amount_numeric, amount_type):
    # none and 0 checks 
    amount_type=str(amount_type)
    if amount_words and not str(amount_words).replace(' ', '').isdigit() and str(amount_words) != 'nan':
        amount_in_words = amount_words
    else:
        amount = int(amount_numeric.replace(',', ''))
        if amount == 0:
            return f', no declared {amount_type} <mark name="{amount_type}"/>'
        amount_words = p.number_to_words(amount)
        if 'crore' in amount_words.lower():
            unit = 'crore'
        elif 'lakh' in amount_words.lower() or 'lac' in amount_words.lower():
            unit = 'lakh'
        elif 'thou' in amount_words.lower() or 'thous' in amount_words.lower():
            unit = 'thousand'
        else:
            unit = ''
        if unit:
            amount_words = p.plural(unit, amount)
    if amount_type.lower() == 'assets':
        return f', declared assets valued at {amount_in_words} <mark name="{amount_type}"/>'
    elif amount_type.lower() == 'liabilities':
        return f', declared liabilities amounting to {amount_in_words} <mark name="{amount_type}"/>'
    else:
        return f', declared {amount_in_words} of {amount_type} <mark name="{amount_type}"/>'


def process_candidate_audio_strings(row):
    # change this to a beter patter
    
    text_parts ={
        "name": describe_name(row['name']),
        "party": describe_party_affiliation(row['party'],row['party_name']),
        "age": describe_age(row['age']),
        "constituency": describe_constituency(row['constituency']),
        "education": describe_education(row['education']),
        "criminal_cases": describe_criminal_cases(row['criminal_cases']),
        "assets": convert_money_to_words(row['assets_in_words'], row['assets'], 'assets'),
        #check for nan in the data. 
        "liabilities": convert_money_to_words(row['liabilities_in_words'], row['liabilities'], 'liabilities'),
    }
    print(text_parts)
    return text_parts

# %%
def text_for_criminal_cases(cases):
    
    try:
        num_cases = int(cases)
    except ValueError:
        return 'Unknown'
    if num_cases == 0:
        return '0 Criminal'
    else:
        return f'{num_cases} Criminal'

    
# function for assets,assets_in_words,liabilities,liabilities_in_words
def convert_money_to_text(amount_words, amount_numeric, amount_type):
    amount_type=str(amount_type)
    if amount_words and not str(amount_words).replace(' ', '').isdigit() and str(amount_words) != 'nan':
        amount_in_words = amount_words
    else:
        amount = int(amount_numeric.replace(',', ''))
        if amount == 0:
            return f'0'
        amount_words = p.number_to_words(amount)
        if 'crore' in amount_words.lower():
            unit = 'crore'
        elif 'lakh' in amount_words.lower() or 'lac' in amount_words.lower():
            unit = 'lakh'
        elif 'thou' in amount_words.lower() or 'thous' in amount_words.lower():
            unit = 'thousand'
        else:
            unit = ''
        if unit:
            amount_words = p.plural(unit, amount)
    if amount_type.lower() == 'assets':
        return f'{amount_in_words}'
    elif amount_type.lower() == 'liabilities':
        return f'{amount_in_words}'
    else:
        return f' '
    

def process_candidate_video_text(row):
    # change this to a beter patter
    
    text_parts ={
        "name": str(row['name']),
        "party": str(row['party']),
        "age": str(row['age']),
        "constituency": str(row['constituency']),
        "education": str(row['education']),
        "criminal_cases": text_for_criminal_cases(row['criminal_cases']),
        "assets": convert_money_to_text(row['assets_in_words'], row['assets'], 'assets'),
        #check for nan in the data. 
        "liabilities": convert_money_to_text(row['liabilities_in_words'], row['liabilities'], 'liabilities'),
    }
    
    return text_parts

# %%
# generate audio
def send_request_to_tts_api(request_string, output_location, language='en-US'):
    # Set up the API endpoint and parameters
    api_url = 'https://texttospeech.googleapis.com/v1beta1/text:synthesize'
    api_key =  GCP_key
    headers = {'Content-Type': 'application/json'}
    voice=random.choice(voice_options)
    data = {
        'input': {'ssml': str(request_string)},
        "voice": {"languageCode": "en-IN","name": voice.get("name","en-IN-Neural2-A")},
        'audioConfig': {'audioEncoding': 'MP3', "pitch": voice.get("pitch",0),"speakingRate": voice.get("speakingRate",1), "effectsProfileId": ["handset-class-device"]},
        "enableTimePointing": ["SSML_MARK"]
    }
    print("fetching audio", request_string)
    
    # Requesting TTS API
    response = requests.post(f'{api_url}?key={api_key}', headers=headers, json=data)
    
    response.raise_for_status()
    response = response.json()
    # Decoding auding file
    audio_data = base64.b64decode(response["audioContent"])
    audio_file = io.BytesIO(audio_data)
    
    print(response["timepoints"])
    # Save file
    with open(str(output_location) + ".mp3", 'wb') as out_file:
        out_file.write(audio_file.read())
    
    #return  marks dict.
    return response["timepoints"]

# %%
fetch_background_image_locations()
# Out:
# {'name': '/Users/saml16/projects/Elections_info/static/images/image_set/image_colors/green/name.png',
#  'party': '/Users/saml16/projects/Elections_info/static/images/image_set/image_colors/green/name.png',
#  'constituency': '/Users/saml16/projects/Elections_info/static/images/image_set/image_colors/green/victory.png',
#  'age': '/Users/saml16/projects/Elections_info/static/images/image_set/image_colors/green/victory.png',
#  'education': '/Users/saml16/projects/Elections_info/static/images/image_set/image_colors/green/education.png',
#  'criminal_cases': '/Users/saml16/projects/Elections_info/static/images/image_set/image_colors/green/cases.png',
#  'assets': '/Users/saml16/projects/Elections_info/static/images/image_set/image_colors/green/assets.png',
#  'liabilities': '/Users/saml16/projects/Elections_info/static/images/image_set/image_colors/green/assets.png'}

# %%
def make_video(background,video_text,clip_duration, center_image=None, profile_picture=None, party_picture=None):
    
    background = ImageClip(background, duration=clip_duration)
    if center_image:
        text = TextClip(video_text.get("name"," ").capitalize(),size=(int(background.w *0.8),100), align=text_clip_props.get('align','North'), font=text_clip_props.get('font','Futura-Bold'), fontsize=text_clip_props.get('fontsize',70), color=text_clip_props.get('color','White'), method=text_clip_props.get('method','caption'), stroke_color=text_clip_props.get('stroke_color','GhostWhite'), stroke_width=text_clip_props.get('stroke_width',1)).set_position(('center','top') ).set_duration(clip_duration)
        text2 = TextClip(video_text.get("content"," ").upper(), size=(int(background.w *0.9),None), align=text_clip_props.get('align','North'), font=text_clip_props.get('font','Futura-Bold'), fontsize=text_clip_props.get('fontsize',120), color=text_clip_props.get('color','White'), method=text_clip_props.get('method','caption'), stroke_color=text_clip_props.get('stroke_color','GhostWhite'), stroke_width=text_clip_props.get('stroke_width',1)).set_position(('center','bottom')).set_duration(clip_duration)
    else:
        text = TextClip(video_text.get("name"," ").capitalize(),size=(int(background.w *0.8),100), align=text_clip_props.get('align','North'), font=text_clip_props.get('font','Futura-Bold'), fontsize=text_clip_props.get('fontsize',70), color=text_clip_props.get('color','White'), method=text_clip_props.get('method','caption'), stroke_color=text_clip_props.get('stroke_color','GhostWhite'), stroke_width=text_clip_props.get('stroke_width',1)).set_position((0.1,0.35),relative=True ).set_duration(clip_duration)
        text2 = TextClip(video_text.get("content"," ").upper(), size=(int(background.w *0.9),None), align=text_clip_props.get('align','North'), font=text_clip_props.get('font','Futura-Bold'), fontsize=text_clip_props.get('fontsize',120), color=text_clip_props.get('color','White'), method=text_clip_props.get('method','caption'), stroke_color=text_clip_props.get('stroke_color','GhostWhite'), stroke_width=text_clip_props.get('stroke_width',1)).set_position((0.05,0.43),relative=True).set_duration(clip_duration)

    clips=[background, text, text2]
    if center_image and os.path.isfile(center_image):
        profile= ImageClip(center_image).set_duration(clip_duration).set_position('center').resize(height=background.h*0.4, width=background.w*0.4).crossfadein(clip_duration*0.1).crossfadeout(clip_duration*0.2)

        clips.append(profile)

    if profile_picture and os.path.isfile(profile_picture):
        profile_top= ImageClip(profile_picture).set_duration(clip_duration).set_position(('left','top')).resize(height=background.h*0.2, width=background.w*0.2)

        clips.append(profile_top)

    if party_picture and os.path.isfile(party_picture):
        profile_top= ImageClip(party_picture).set_duration(clip_duration).set_position(('right','top')).resize(height=background.h*0.2, width=background.w*0.2)

        clips.append(profile_top)

    return CompositeVideoClip(clips)

# %%
help(TextClip)
# Out:
# Help on class TextClip in module moviepy.video.VideoClip:
#
# class TextClip(ImageClip)
#  |  TextClip(txt=None, filename=None, size=None, color='black', bg_color='transparent', fontsize=None, font='Courier', stroke_color=None, stroke_width=1, method='label', kerning=None, align='center', interline=None, tempfilename=None, temptxt=None, transparent=True, remove_temp=True, print_cmd=False)
#  |
#  |  Class for autogenerated text clips.
#  |
#  |  Creates an ImageClip originating from a script-generated text image.
#  |  Requires ImageMagick.
#  |
#  |  Parameters
#  |  -----------
#  |
#  |  txt
#  |    A string of the text to write. Can be replaced by argument
#  |    ``filename``.
#  |
#  |  filename
#  |    The name of a file in which there is the text to write.
#  |    Can be provided instead of argument ``txt``
#  |
#  |  size
#  |    Size of the picture in pixels. Can be auto-set if
#  |    method='label', but mandatory if method='caption'.
# ...

# %%
background = '/Users/saml16/projects/Elections_info/static/images/image_set/image_colors/yellow/name.png'
video_text = {'name':'Cases', 'content':'CheckMYCriminaisabadthinghowthingschange'}


name_v=make_video(background,video_text,4, center_image=None, profile_picture=None, party_picture=None)
name_v.duration
name_v.ipython_display(fps=120)
# Out:
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
# set size 
# check font color and other details. 


def create_video( audio_timings, video_text, nem_id, party_id ):
    background_images=fetch_background_image_locations()
    
    if audio_timings.get('name',None):
        videos=[]
        
        # Name
        profile_image=profile_path+str(nem_id)+".jpg"
        name_v = make_video(background_images['name'],{'name':'name', 'content':video_text['name']},audio_timings['name'], center_image=profile_image, profile_picture=None, party_picture=None)
        videos.append(name_v)
    else:
        return 
    
    #text = TextClip("Akbaruddin Owaisi Akbaruddin Owaisi Akbaruddin Owaisi".upper(), align='North', font='Bodoni-72-Oldstyle-Bold', fontsize=72, font='Bodoni-72-Oldstyle-Bold', color='goldenrod1', stroke_color='GhostWhite',  stroke_width=1, method='caption').set_position('center').set_duration(2.451604127883911)
    
    
    if audio_timings.get('party',None):
        # Party
        party_duration=audio_timings['party']- audio_timings['name']
        party_image=party_path+str(party_id)+".png"
        party_v = make_video(background_images['party'],{'name':'party', 'content':video_text['party']},party_duration, center_image=party_image, profile_picture=profile_image, party_picture=None)
        videos.append(party_v)
    
    
    
    if audio_timings.get('constituency',None) and audio_timings.get('party',None):
        # constituency 
        ######## change this if no constitunecy

        constituency_duration=audio_timings['constituency']- audio_timings['party']
        constituency_v = make_video(background_images['party'],{'name':'constituency', 'content':video_text['constituency']},constituency_duration, center_image=None, profile_picture=profile_image, party_picture=party_image)
        videos.append(constituency_v)
    
    if audio_timings.get('age',None) and audio_timings.get('constituency',None):
        # Age
        age_duration=audio_timings['age']- audio_timings['constituency']
        age_v = make_video(background_images['age'],{'name':'age', 'content':video_text['age']},age_duration, center_image=None, profile_picture=profile_image, party_picture=party_image)
        videos.append(age_v)
    
    if audio_timings.get('education',None) and audio_timings.get('age',None):
    
        # Education
        education_duration=audio_timings['education']- audio_timings['age']
        education_v = make_video(background_images['education'],{'name':'education', 'content':video_text['education']},education_duration, center_image=None, profile_picture=profile_image, party_picture=party_image)
        videos.append(education_v)

    
    if audio_timings.get('criminal_cases',None) and audio_timings.get('education',None):
    
        # Criminal_cases
        cases_duration=audio_timings['criminal_cases']- audio_timings['education']
        cases_v = make_video(background_images['criminal_cases'],{'name':'Cases', 'content':video_text['criminal_cases']},cases_duration, center_image=None, profile_picture=profile_image, party_picture=party_image)
        videos.append(cases_v)
    
    
    if audio_timings.get('assets',None) and audio_timings.get('criminal_cases',None):
        # Assets
        assets_duration=audio_timings['assets']- audio_timings['criminal_cases']
        assets_v = make_video(background_images['assets'],{'name':'assets', 'content':video_text['assets']},assets_duration, center_image=None, profile_picture=profile_image, party_picture=party_image)
        videos.append(assets_v)
    
    
    
    if audio_timings.get('liabilities',None) and audio_timings.get('assets',None):
        # Liabilities
        liabilities_duration=audio_timings['liabilities']- audio_timings['assets']
        liabilities_v = make_video(background_images['liabilities'],{'name':'liabilities', 'content':video_text['liabilities']},liabilities_duration, center_image=None, profile_picture=profile_image, party_picture=party_image)
        print("liabilites,,",end="\t")
        videos.append(liabilities_v)
    
    
    # Combine video
    final_clip = concatenate_videoclips(videos)
    
    
    # Load the audio file
    audio = AudioFileClip(audio_clip_location+str(nem_id)+".mp3")

    
    if notice_image_path and os.path.isfile(notice_image_path):
        notice_clip= ImageClip(notice_image_path, duration=2)
        final_clip = concatenate_videoclips([final_clip,notice_clip])
    
    audio_background = AudioFileClip('/Users/saml16/projects/Elections_info/static/background/vm_f.mp3').set_duration(final_clip.duration).volumex(0.05)
    final_audio = CompositeAudioClip([audio, audio_background])

    
    # Set the audio of the video clip
    video = final_clip.set_audio(final_audio)

    video.write_videofile(output_location+str(nem_id)+".mp4", fps=60)
    audio.close()
    
    return video

# %%
help(AudioFileClip)
# Out:
# Help on class AudioFileClip in module moviepy.audio.io.AudioFileClip:
#
# class AudioFileClip(moviepy.audio.AudioClip.AudioClip)
#  |  AudioFileClip(filename, buffersize=200000, nbytes=2, fps=44100)
#  |
#  |  An audio clip read from a sound file, or an array.
#  |  The whole file is not loaded in memory. Instead, only a portion is
#  |  read and stored in memory. this portion includes frames before
#  |  and after the last frames read, so that it is fast to read the sound
#  |  backward and forward.
#  |
#  |  Parameters
#  |  ------------
#  |
#  |  filename
#  |    Either a soundfile name (of any extension supported by ffmpeg)
#  |    or an array representing a sound. If the soundfile is not a .wav,
#  |    it will be converted to .wav first, using the ``fps`` and
#  |    ``bitrate`` arguments.
#  |
#  |  buffersize:
#  |    Size to load in memory (in number of frames)
#  |
#  |
#  |  Attributes
#  |  ------------
#  |
#  |  nbytes
# ...

# %%
combined.to_csv('/Users/saml16/projects/Elections_info/static/Loksabha2019/Winners/candidates_data_with_party.csv',index=False)

# %%
combined
# Out:
#                            name     constituency  nem_candidate_id party  \
# 0                Bapu Rao Soyam         ADILABAD              5069   BJP
# 1         Satyapal Singh Baghel             AGRA              5522   BJP
# 2    Patel Hasmukhbhai Somabhai   AHMEDABAD EAST              9386   BJP
# 3         Dr. Solanki Kiritbhai   AHMEDABAD WEST              8488   BJP
# 4      Sujay Radhakrishna Vikhe       AHMEDNAGAR              8513   BJP
# ..                          ...              ...               ...   ...
# 532  Ramdas Chandrabhanji Tadas           WARDHA              4885   BJP
# 533                Rahul Gandhi          WAYANAD              9208   INC
# 534         Parvesh Sahib Singh       WEST DELHI             12717   BJP
# 535   Bhavana Pundlikrao Gawali  YAVATMAL WASHIM              5748   SHS
# 536                   B.B.Patil        ZAHIRABAD              6753   BRS
#
#      criminal_cases      education  age        assets assets_in_words  \
# ...

# %%
test=combined.iloc[[43,44,45,46]]
test
# Out:
#                                       name constituency  nem_candidate_id  \
# 43  Gaddigoudar Parvatagouda Chandanagouda     BAGALKOT              7248
# 44                      Dr. Satyapal Singh      BAGHPAT              6144
# 45                  Adhir Ranjan Chowdhury   BAHARAMPUR             10085
# 46                          Akshayabar Lal     BAHRAICH             11039
#
#    party  criminal_cases              education  age        assets  \
# 43   BJP               0  Graduate Professional   68   4,39,80,663
# 44   BJP               1          Post Graduate   63   7,81,95,793
# 45   INC               7              10th Pass   63  10,13,15,437
# 46   BJP               0              10th Pass   73   4,56,91,463
#
#    assets_in_words liabilities liabilities_in_words  \
# 43         4 Crore   79,87,991              79 Lacs
# 44         7 Crore           0                  NaN
# 45        10 Crore   85,06,984              85 Lacs
# ...

# %%
def get_timings(audio_timings):
    timings={}
    for i in audio_timings:
        if 'markName' in i:
            timings[i['markName']]=i['timeSeconds']
    return timings

# %%
for row in test.to_dict(orient='records'):

    #print(row)
    # generate text ssml.
    audio_text_dict=process_candidate_audio_strings(row)
    print(audio_text_dict)
    
    audio_text= "".join(['<speak>',audio_text_dict.get('name',""), audio_text_dict.get('party',""),audio_text_dict.get('constituency',""), audio_text_dict.get('age',""), audio_text_dict.get('education',""), audio_text_dict.get('criminal_cases',""),", has" if audio_text_dict.get('assets',"") else "" ,audio_text_dict.get('assets',""),"and" if audio_text_dict.get('liabilities',"") else "", audio_text_dict.get('liabilities',"") , '</speak>'])
    #print(audio_text)
    #test_a_t='<speak>Hello <mark name="timepoint_1"/> Mark. Good to <mark name="timepoint_2"/> see you.</speak>'
    audio_timings=send_request_to_tts_api(audio_text,'/Users/saml16/projects/Elections_info/static/Loksabha2019/Winners/audio/'+str(row['nem_candidate_id']))
    # generate audio
    timings =get_timings(audio_timings)
    # read timings 
    #print(timings)
    # create videos 
    video_text=process_candidate_video_text(row)
    #print(video_text)
    print(row.get('nem_party_id',None))

    create_video(timings, video_text, row.get('nem_candidate_id',None), int(row.get('nem_party_id') or 0) )

    video_location=output_location+str(row.get('nem_candidate_id',0))+".mp4"
    profile_location=  profile_path+str(row.get('nem_candidate_id',0))+".jpg"
    party_location = party_path+str(row.get('nem_party_id',0))+".png"
    #add_images_to_top(video_location,(profile_path,party_location),(timings['name'],timings['party']) )
    # create overlap. 
    # Save Video
# Out:
# {'name': 'Candidate name: <prosody rate="slow">Gaddigoudar Parvatagouda Chandanagouda</prosody><mark name="name"/>', 'party': ', is a member of the Bharatiya Janata Party  <mark name="party"/>', 'age': ', at the age of 68<mark name="age"/>', 'constituency': ', has won the BAGALKOT seat<mark name="constituency"/>', 'education': ', is a Graduate Professional<mark name="education"/>', 'criminal_cases': ', with no criminal cases on record<mark name="criminal_cases"/>', 'assets': ', declared assets valued at 4 Crore <mark name="assets"/>', 'liabilities': ', declared liabilities amounting to 79 Lacs <mark name="liabilities"/>'}
# ...

# %%
combined.isna()

# %%
TextClip.list('color')

# %%
name_v.duration

# %%
help(TextClip)

# %%
# set size 
# check font color and other details. 




def create_video_old( audio_timings, video_text, nem_id, party_id ):
    
    videos=[]
   
    # Name
    background = get_background_clip(background_images['name'],audio_timings['name'])
    #text = get_text_clip(video_text['name'],audio_timings['name'], 'bottom' )
    text = TextClip(video_text['name'], align='North', fontsize=72, font='Bodoni-72-Oldstyle-Bold', color='goldenrod1', stroke_color='GhostWhite',  stroke_width=1, method='caption').set_position('bottom').set_duration(audio_timings['name'])
    image_clips=[background, text]
    if os.path.isfile(profile_path+str(nem_id)+".jpg"):
        profile= ImageClip(profile_path+str(nem_id)+".jpg").set_duration(audio_timings['name']).set_position('center').resize(height=background.h *0.8, width=background.w*0.8).crossfadein(audio_timings['name']*0.1).crossfadeout(audio_timings['name']*0.1)
        image_clips.append(profile)
    
    name_v = CompositeVideoClip(image_clips)
    name_v = make_video(background_images['name'],{'name':video_text['name']},audio_timings['name'], center_image=profile_path+str(nem_id)+".jpg", profile_picture=None, party_picture=None)
    videos.append(name_v)
    
    #text = TextClip("Akbaruddin Owaisi Akbaruddin Owaisi Akbaruddin Owaisi".upper(), align='North', font='Bodoni-72-Oldstyle-Bold', fontsize=72, font='Bodoni-72-Oldstyle-Bold', color='goldenrod1', stroke_color='GhostWhite',  stroke_width=1, method='caption').set_position('center').set_duration(2.451604127883911)
    
    
    # Party
    party_duration=audio_timings['party']- audio_timings['name']
    
    background =get_background_clip(background_images['party'],party_duration) 
    #text = get_text_clip(video_text['party'],party_duration, 'bottom' )
    text = TextClip(video_text['party'], align='North', fontsize=72, font='Bodoni-72-Oldstyle-Bold', color='goldenrod1', stroke_color='GhostWhite',  stroke_width=1, method='caption').set_position('bottom').set_duration(party_duration)
    
    party_clips=[background, text]
    if os.path.isfile(party_path+str(party_id)+".png"):
        profile= ImageClip(party_path+str(party_id)+".png").set_duration(party_duration).set_position('center').resize(height=background.h *0.8, width=background.w*0.8).crossfadein(party_duration*0.1).crossfadeout(party_duration*0.1)
        party_clips.append(profile)
    
    party_v = CompositeVideoClip(party_clips)
    videos.append(party_v)
    
    
    
    # constituency 
    ######## change this if no constitunecy
    
    constituency_duration=audio_timings['constituency']- audio_timings['party']
    
    background =get_background_clip(background_images['party'],constituency_duration) 
    #text = get_text_clip(video_text['constituency'],constituency_duration, 'center' )
    #background = ImageClip(background_images['name'], duration=constituency_duration)
    
    text = TextClip(video_text['constituency'], align='North', fontsize=72, font='Bodoni-72-Oldstyle-Bold', color='goldenrod1', stroke_color='GhostWhite',  stroke_width=1, method='caption').set_position('bottom').set_duration(constituency_duration)
    
    constituency_v = CompositeVideoClip([background, text])
    videos.append(constituency_v)
    
    
    # Age
    age_duration=audio_timings['age']- audio_timings['constituency']
    
    background =get_background_clip(background_images['age'],age_duration) 
    #text = get_text_clip(video_text['age'],age_duration, 'center' )
    #background = ImageClip(background_images['name'], duration=constituency_duration)
    text = TextClip(video_text['age'], align='North', fontsize=72, font='Bodoni-72-Oldstyle-Bold', color='goldenrod1', stroke_color='GhostWhite',  stroke_width=1, method='caption').set_position('bottom').set_duration(age_duration)
        
    age_v = CompositeVideoClip([background, text])
    videos.append(age_v)
    
    
    # Education
    education_duration=audio_timings['education']- audio_timings['age']
    
    background =get_background_clip(background_images['education'],education_duration) 
    #text = get_text_clip(video_text['education'],education_duration, 'center' )
    #background = ImageClip(background_images['name'], duration=constituency_duration)
    text = TextClip(video_text['education'],  align='North', fontsize=72, font='Bodoni-72-Oldstyle-Bold', color='goldenrod1', stroke_color='GhostWhite',  stroke_width=1, method='caption').set_position('bottom').set_duration(education_duration)
    
    education_v = CompositeVideoClip([background, text])
    videos.append(education_v)
    

    # Criminal_cases
    cases_duration=audio_timings['criminal_cases']- audio_timings['education']
    
    background =get_background_clip(background_images['criminal_cases'],education_duration) 
    #text = get_text_clip(video_text['criminal_cases'],education_duration, 'center' )
    #background = ImageClip(background_images['name'], duration=constituency_duration)
    text = TextClip(video_text['criminal_cases'], align='North', fontsize=72, font='Bodoni-72-Oldstyle-Bold', color='goldenrod1', stroke_color='GhostWhite',  stroke_width=1, method='caption').set_position('bottom').set_duration(cases_duration)
    
    cases_v = CompositeVideoClip([background, text])
    videos.append(cases_v)
    
    
    
    # Assets
    assets_duration=audio_timings['assets']- audio_timings['criminal_cases']
    
    background =get_background_clip(background_images['assets'],assets_duration) 
    #text = get_text_clip(video_text['assets'],assets_duration, 'center' )
    #background = ImageClip(background_images['name'], duration=constituency_duration)
    text = TextClip(video_text['assets'], align='North', fontsize=72, font='Bodoni-72-Oldstyle-Bold', color='goldenrod1', stroke_color='GhostWhite',  stroke_width=1, method='caption').set_position('bottom').set_duration(assets_duration)
    
    assets_v = CompositeVideoClip([background, text])
    videos.append(assets_v)
    
    
    
    # Liabilities
    liabilities_duration=audio_timings['liabilities']- audio_timings['assets']
    
    background =get_background_clip(background_images['liabilities'],liabilities_duration) 
    #text = get_text_clip(video_text['liabilities'],liabilities_duration, 'center' )
    #background = ImageClip(background_images['name'], duration=constituency_duration)
    text = TextClip(video_text['liabilities'], align='North', fontsize=72, font='Bodoni-72-Oldstyle-Bold', color='goldenrod1', stroke_color='GhostWhite',  stroke_width=1, method='caption').set_position('bottom').set_duration(liabilities_duration)
    
    liabilities_v = CompositeVideoClip([background, text])
    videos.append(liabilities_v)
    
    # Combine video
    final_clip = concatenate_videoclips(videos)
    
    
    # Load the audio file
    audio = AudioFileClip(audio_clip_location+str(nem_id)+".mp3")
    audio_background = mpe.AudioFileClip('/Users/saml16/projects/Elections_info/static/background/vm_f.mp3')
    final_audio = mpe.CompositeAudioClip([my_clip.audio, audio_background])

    
    # Set the audio of the video clip
    video = final_clip.set_audio(final_audio)
    
    video.write_videofile(output_location+str(nem_id)+".mp4", fps=60)
    return video

# %%
# overlap of images

def add_image(video_location, image_location,timing, position='center', relative_size=0.2):
    video= VideoFileClip(video_location)
    #make image clip
    
    image1 = ImageClip(image_location).set_start(timing).set_end(video.duration)
    image1_det = image1.set_position(position).resize(height=video.h *relative_size)
    if relative_size == 0.8:
        image1_det= image1_det.crossfadein(1)
    
    video = CompositeVideoClip([video, image1_det])
    
    video.write_videofile(video_location, fps=24)
    return video

    
def add_images_to_top(video_location, image_locations, timings):

    if len(image_locations)>1:
        # overlay first image 20% top right
        if os.path.isfile(image_locations[1]):
            add_image(video_location, image_locations[1], timings[1], ('right','top'), 0.2)
    # overlay first image 20% top left
    if os.path.isfile(image_locations[0]):
        add_image(video_location,image_locations[0], timings[0], ('left','top'), 0.2)
    
    add_image(video_location,"/Users/saml16/projects/Elections_info/static/cabinet/images/ADR.png", 0, ('left','bottom'), 0.1)
    # overlay first image 20% top right
    add_image(video_location, "/Users/saml16/projects/Elections_info/static/cabinet/images/myneta.png",0,  ('right','bottom'), 0.1)

# %%
import numpy as np
#combined = combined.drop(columns=['serial_number','image_link','details_link','new_id'])
combined = combined.replace({np.nan:None})
combined[combined['party_name'].isna()]
combined = pd.read_csv('/Users/saml16/projects/Elections_info/static/Loksabha2019/Winners/candidates_data_with_party.csv')  
combined = combined.drop(columns=['serial_number','image_link','details_link','new_id'])
# Out:
#                                                name            constituency  \
# 17                                Navneet Ravi Rana                AMRAVATI
# 123                            Thirumaavalavan Thol             CHIDAMBARAM
# 134                      Delkar Mohanbhai Sanjibhai  DADRA AND NAGAR HAVELI
# 287                              Naba Kumar Sarania               KOKRAJHAR
# 332                             Sumalatha Ambareesh                  MANDYA
# 343                            Anupriya Singh Patel                MIRZAPUR
# 353                                   Arvind Sawant            MUMBAI SOUTH
# 388  Omprakash Bhupalsinh Alias Pavan Rajenimbalkar               OSMANABAD
# 395                  Jadhav Sanjay (Bandu) Haribhau                PARBHANI
# 434                            Vinayak Bhaurao Raut    RATNAGIRI SINDHUDURG
# 437                                     Pakauri Lal             ROBERTSGANJ
# ...

# %%
combined2 = pd.read_csv('/Users/saml16/projects/Elections_info/static/Loksabha2019/Winners/candidates_data_with_party.csv')  
combined2 = combined2.drop(columns=['party_image_link'])
combined2
# Out:
#                            name     constituency  nem_candidate_id party  \
# 0                Bapu Rao Soyam         ADILABAD              5069   BJP
# 1         Satyapal Singh Baghel             AGRA              5522   BJP
# 2    Patel Hasmukhbhai Somabhai   AHMEDABAD EAST              9386   BJP
# 3         Dr. Solanki Kiritbhai   AHMEDABAD WEST              8488   BJP
# 4      Sujay Radhakrishna Vikhe       AHMEDNAGAR              8513   BJP
# ..                          ...              ...               ...   ...
# 532  Ramdas Chandrabhanji Tadas           WARDHA              4885   BJP
# 533                Rahul Gandhi          WAYANAD              9208   INC
# 534         Parvesh Sahib Singh       WEST DELHI             12717   BJP
# 535   Bhavana Pundlikrao Gawali  YAVATMAL WASHIM              5748   SHS
# 536                   B.B.Patil        ZAHIRABAD              6753   BRS
#
#      criminal_cases      education  age        assets assets_in_words  \
# ...

# %%
combined2.to_csv('/Users/saml16/projects/Elections_info/static/Loksabha2019/Winners/candidates_data_with_party.csv',index=False)

# %%
# fetch data
data=pd.read_csv("/Users/saml16/projects/Elections_info/static/Loksabha2019/Winners/candidates_data.csv")
test= data[0:2]
#main function
winners=pd.read_csv("/Users/saml16/projects/Elections_info/static/Loksabha2019/Winners/candidates_data.csv")
party=pd.read_csv('/Users/saml16/projects/Elections_info/static/Party/party.csv')
party=party.rename(columns={'alt':'party', 'href':'party_image_link', 'name':'party_name'})
# Define a custom function
parties_reference= {
'YSRCP':'YSR Congress Party',
 'IND': 'Independent',
 'Jammu & Kashmir National Conference':'JKNC',
 'TRS':'BRS',
 'AJSU Party':'AJSU',
 'Revolutionary Socialist Party':'RSP',
 'Kerala Congress (M)':'KC(M)',
 'Nationalist Democratic Progressive Party':'NDPP',
 'Rashtriya Loktantrik Party':'RLTP',
 'Sikkim Krantikari Morcha':'SKM'
}

def replace_party(party):
    return parties_reference.get(party, party)

winners['party'] = winners['party'].apply(replace_party)
combined=pd.merge(winners,party, on='party',how='left')
combined.to_csv('/Users/saml16/projects/Elections_info/static/Loksabha2019/Winners/candidates_data_with_party.csv',index=False)
combined
# Out:
#                            name  \
# 0                Bapu Rao Soyam
# 1         Satyapal Singh Baghel
# 2    Patel Hasmukhbhai Somabhai
# 3         Dr. Solanki Kiritbhai
# 4      Sujay Radhakrishna Vikhe
# ..                          ...
# 532  Ramdas Chandrabhanji Tadas
# 533                Rahul Gandhi
# 534         Parvesh Sahib Singh
# 535   Bhavana Pundlikrao Gawali
# 536                   B.B.Patil
#
#                                           details_link  new_id  \
# 0    https://www.myneta.info/LokSabha2019//candidat...    5069
# 1    https://www.myneta.info/LokSabha2019//candidat...    5522
# 2    https://www.myneta.info/LokSabha2019//candidat...    9386
# 3    https://www.myneta.info/LokSabha2019//candidat...    8488
# 4    https://www.myneta.info/LokSabha2019//candidat...    8513
# ..                                                 ...     ...
# 532  https://www.myneta.info/LokSabha2019//candidat...    4885
# ...
